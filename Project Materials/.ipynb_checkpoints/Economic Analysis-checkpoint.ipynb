# %% [markdown]
# ## Conducting an Analysis of the economic effects of warehouse
#
# Often, proponents of warehouses have always touted the economic benefits it brings to communities. Using the warehouse data set we use previously along with block group data from the ACS 5year for 2019 and 2010, we can seek to the investigate their true effects. Here is a source for the [2019](https://data.census.gov/table?q=Ontario+city,+California&tid=ACSST5Y2019.S0501) and [2010](https://data.census.gov/table?q=Ontario+city,+California&tid=ACSST5Y2010.S0501) data

# %%
#importing the neccesary libraries
# !pip install pointpats

from pointpats import centrography
import pandas as pd
import geopandas as gpd
import plotly as plt
import folium 
import matplotlib.pyplot as mplt
import contextily as ctx
from shapely import wkt
from shapely.wkt import loads
import plotly.express as px
import osmnx as ox
import numpy as np
#import centragraphy analysis functions
from pointpats.centrography import hull, mbr, mean_center, weighted_mean_center, manhattan_median, std_distance,euclidean_median,ellipse


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# Out:
# Requirement already satisfied: pointpats in /opt/conda/lib/python3.10/site-packages (2.3.0)
# Requirement already satisfied: numpy>=1.3 in /opt/conda/lib/python3.10/site-packages (from pointpats) (1.23.5)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from pointpats) (1.5.2)
# Requirement already satisfied: scipy>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from pointpats) (1.10.0)
# Requirement already satisfied: libpysal>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from pointpats) (4.7.0)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from pointpats) (3.6.2)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from libpysal>=4.0.0->pointpats) (2.28.1)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from libpysal>=4.0.0->pointpats) (22.0)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from libpysal>=4.0.0->pointpats) (2.6.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from libpysal>=4.0.0->pointpats) (3.1.2)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from libpysal>=4.0.0->pointpats) (4.11.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats) (1.0.6)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats) (9.4.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->pointpats) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->pointpats) (2022.7)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->pointpats) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->libpysal>=4.0.0->pointpats) (2.3.2.post1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->libpysal>=4.0.0->pointpats) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->libpysal>=4.0.0->pointpats) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->libpysal>=4.0.0->pointpats) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->libpysal>=4.0.0->pointpats) (2022.12.7)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->libpysal>=4.0.0->pointpats) (2.1.1)

# %%
#import data sets
Ontario_boundary = gpd.read_file('../Data/Ontario Boundary/Ontario Boundary.shp')

SB_County_Block_Group_Employment = pd.read_csv('../Data/SB_County_Block_Group_Employment_2010_2019.csv')
SB_County_Block_Group_Employment = gpd.GeoDataFrame(
    SB_County_Block_Group_Employment.loc[:, [c for c in SB_County_Block_Group_Employment.columns if c != "geometry"]],
    geometry=gpd.GeoSeries.from_wkt(SB_County_Block_Group_Employment["geometry"]),
    crs="epsg:4326",
)
Warehouse_Parcel_Geo =gpd.read_file('../Data/warehousemaps.geojson')

Warehouse_Parcel_Geo = Warehouse_Parcel_Geo.to_crs(epsg=4326)
Ontario_boundary = Ontario_boundary.to_crs(epsg=4326)
Ontario_boundary=Ontario_boundary.loc[Ontario_boundary['CITY'] == 'Ontario']

SB_County_Block_Group_Employment.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1060 entries, 0 to 1059
# Data columns (total 30 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   Unnamed: 0                                                          1060 non-null   int64
#  1   STATEFP                                                             1060 non-null   int64
#  2   COUNTYFP                                                            1060 non-null   int64
#  3   TRACTCE                                                             1060 non-null   int64
#  4   BLKGRPCE                                                            1060 non-null   int64
#  5   GEOID                                                               1060 non-null   int64
#  6   NAMELSAD                                                            1060 non-null   object
#  7   MTFCC                                                               1060 non-null   object
#  8   FUNCSTAT                                                            1060 non-null   object
#  9   ALAND                                                               1060 non-null   int64
#  10  AWATER                                                              1060 non-null   int64
#  11  INTPTLAT                                                            1060 non-null   float64
#  12  INTPTLON                                                            1060 non-null   float64
#  13  Geo_GEOID_x                                                         1060 non-null   object
#  14  Female Transportation and Material Moving Occupations 2019          1060 non-null   float64
#  15  Total Population 2019                                               1060 non-null   int64
#  16  Population Density (Per Sq. Mile) 2019                              1060 non-null   float64
#  17  Male Transportation and Material Moving Occupations 2019            1060 non-null   float64
#  18  Median Household Income (In 2019 Inflation Adjusted Dollars) 2019   1060 non-null   float64
#  19  Geo_GEOID_y                                                         1060 non-null   object
#  20  Female Transportation and Material Moving Occupations 2010          1060 non-null   float64
#  21  Total Population 2010                                               1060 non-null   int64
#  22  Population Density (Per Sq. Mile) 2010                              1060 non-null   float64
#  23  Male Transportation and Material Moving Occupations 2010            1060 non-null   float64
#  24  Median Household Income (In 2019 Inflation Adjusted Dollars) 2010   1060 non-null   float64
#  25  Change in Median Household Income from 2010 to 2019 (2019 dollars)  1060 non-null   float64
#  26  Transportation and Material Moving Occupations 2019                 1060 non-null   float64
#  27  Transportation and Material Moving Occupations 2010                 1060 non-null   float64
#  28  Change in Warehouse Employment from 2010 to 2019                    1060 non-null   float64
#  29  geometry                                                            1060 non-null   geometry
# dtypes: float64(14), geometry(1), int64(10), object(5)
# memory usage: 248.6+ KB

# %%
#get limits of ontario city
xylim = Ontario_boundary.geometry.total_bounds
xlim = ([xylim[0],  xylim[2]])
ylim = ([xylim[1],  xylim[3]])

# %%
#Keep only warehouses built between 
Warehouse_Parcel_Geo1 = Warehouse_Parcel_Geo[(Warehouse_Parcel_Geo['Year built'] >= 2010) & (Warehouse_Parcel_Geo['Year built'] <= 2019)]

# %% [markdown]
# ## Change In Warehouse Employment
#
# While the ACS 5 year does not collect warehouse specfic job counts on the block group level, we can use "Transportation and Material Moving Occupations" as a proxy for warehouse and its related jobs. We compare data from 2010 to 2019 for two reasons. Firstly, during this period the shapes of the block groups do not change allowing us to create a better 1 to 1 analysis. Additionally, there was a large growth in warehouses starting in 2011 as part of the bounch back from '08 recession.

# %%
#plot
# Loop the variables
variable = 'Change in Warehouse Employment from 2010 to 2019'
ax = SB_County_Block_Group_Employment.plot(column=variable, cmap='RdBu', edgecolor="white", legend=True, vmax=600, vmin=-600)
Warehouse_Parcel_Geo1.centroid.plot(ax=ax, color='orange',markersize=2);
Ontario_boundary.plot(ax=ax, facecolor="none", edgecolor="grey", lw=4)
ax.set_title(variable)
ax.set_axis_off()
#ctx.add_basemap(ax, crs=4326);
ax.set_xlim(xlim)
ax.set_ylim(ylim)
# Out:
# /tmp/ipykernel_243/4135655378.py:5: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   Warehouse_Parcel_Geo1.centroid.plot(ax=ax, color='orange',markersize=2);
# (33.97530509018128, 34.09325978152058)

# %%
#plot
# Loop the variables
#SB_County_Block_Group_Employment['centroid'] = SB_County_Block_Group_Employment.geometry.centroid
#pip_mask = SB_County_Block_Group_Employment.within(Ontario_boundary['geometry'])
#SB_County_Block_Group_Employment = SB_County_Block_Group_Employment.loc[pip_mask]

variable = 'Change in Median Household Income from 2010 to 2019 (2019 dollars)'
ax = SB_County_Block_Group_Employment.plot(column=variable,  cmap='RdBu', edgecolor="white", legend=True, vmax=80000, vmin=-80000)
Warehouse_Parcel_Geo1.centroid.plot(ax=ax, color='orange',markersize=2);
Ontario_boundary.plot(ax=ax, facecolor="none", edgecolor="grey", lw=4)
ax.set_title(variable)
ax.set_axis_off()
#ctx.add_basemap(ax, crs=4326);
ax.set_xlim(xlim)
ax.set_ylim(ylim)
# Out:
# /tmp/ipykernel_243/2997383316.py:9: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   Warehouse_Parcel_Geo1.centroid.plot(ax=ax, color='orange',markersize=2);
# (33.97530509018128, 34.09325978152058)

# %% [markdown]
# ##

# %%
#finding the weighted mean for population in ontario
SB_County_Block_Group_Employment["x"] = SB_County_Block_Group_Employment.geometry.centroid.x
SB_County_Block_Group_Employment["y"] = SB_County_Block_Group_Employment.geometry.centroid.y
Warehouse_Parcel_Geo["x"] = Warehouse_Parcel_Geo.geometry.centroid.x
Warehouse_Parcel_Geo["y"] = Warehouse_Parcel_Geo.geometry.centroid.y


SB_County_Block_Group_Employment['centroid'] = SB_County_Block_Group_Employment.geometry.centroid
pip_mask = SB_County_Block_Group_Employment.within(Ontario_boundary['geometry'])

BGwmc = weighted_mean_center(SB_County_Block_Group_Employment[['x','y']], SB_County_Block_Group_Employment['Total Population 2019']) 

Warehouse_Mean_Center = centrography.mean_center(Warehouse_Parcel_Geo[['x','y']])
#BGmajor, BGminor, BGrotation = centrography.ellipse(gdf[['x','y']])
# Out:
# /tmp/ipykernel_243/644142521.py:2: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   SB_County_Block_Group_Employment["x"] = SB_County_Block_Group_Employment.geometry.centroid.x
# /tmp/ipykernel_243/644142521.py:3: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   SB_County_Block_Group_Employment["y"] = SB_County_Block_Group_Employment.geometry.centroid.y
# /tmp/ipykernel_243/644142521.py:4: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   Warehouse_Parcel_Geo["x"] = Warehouse_Parcel_Geo.geometry.centroid.x
# /tmp/ipykernel_243/644142521.py:5: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   Warehouse_Parcel_Geo["y"] = Warehouse_Parcel_Geo.geometry.centroid.y
# /tmp/ipykernel_243/644142521.py:8: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   SB_County_Block_Group_Employment['centroid'] = SB_County_Block_Group_Employment.geometry.centroid
# /opt/conda/lib/python3.10/site-packages/geopandas/base.py:31: UserWarning: The indices of the two GeoSeries are different.
#   warn("The indices of the two GeoSeries are different.")

# %%
# Make the mean centers into geodataframes for plotting
BGwmc_df = pd.DataFrame(np.array([['Weight Mean Population Center', BGwmc[0], BGwmc[1]]]),
                   columns=['Label', 'lat', 'long'])
Warehouse_df = pd.DataFrame(np.array([['Mean Warehouse Center', Warehouse_Mean_Center[0], Warehouse_Mean_Center[1]]]),
                   columns=['Label', 'lat', 'long'])
BGwmc_gdf = gpd.GeoDataFrame(BGwmc_df, geometry=gpd.points_from_xy(BGwmc_df['lat'], BGwmc_df['long']))
Warehouse_gdf = gpd.GeoDataFrame(Warehouse_df, geometry=gpd.points_from_xy(Warehouse_df['lat'], Warehouse_df['long']))

# %%
variable = 'Total Population 2019'
ax = SB_County_Block_Group_Employment.plot(column=variable,  cmap='Blues', edgecolor="white", legend=True, vmax=10000, vmin=0)
BGwmc_gdf.plot(ax=ax, color='blue',markersize=40)
Warehouse_gdf.plot(ax=ax, color='orange',markersize=40)

Ontario_boundary.plot(ax=ax, facecolor="none", edgecolor="grey", lw=4)
ax.set_title(variable)
ax.set_axis_off()
#ctx.add_basemap(ax, crs=4326);
ax.set_xlim(xlim)
ax.set_ylim(ylim)
# Out:
# -117.5830084505887
# (33.97530509018128, 34.09325978152058)
