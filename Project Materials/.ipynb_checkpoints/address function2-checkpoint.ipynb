# %% [markdown]
# ## Import the Libraries

# %%
# to manipulate data
import pandas as pd

# for spatial data
import geopandas as gpd

# for plotting
import matplotlib.pyplot as plt

# for network analysis
import networkx as nx

# for street network analysis
import osmnx as ox

# for basemaps
import contextily as ctx

# for interactive webmaps
import folium

# %% [markdown]
# # The number of warehouses within 1 miles

# %% [markdown]
# ## Define an area of interest

# %%
address = 'Ontario International Airport, Vineyard Avenue, Racimo, Ontario, San Bernardino County, California, 91761, United States'

# %%
# %%time
# %%time is a magic command to see how long it takes this cell to run 

# get the data from OSM that are tagged as 'building' for a 1609.34m X 1609.34m square area
osm = ox.geometries_from_address(address,tags={'building':True},dist=1609.34)
# Out:
# CPU times: user 83.2 ms, sys: 5.78 ms, total: 89 ms
# Wall time: 173 ms

# %%
# show me 10 random rows
osm.sample(5)
# Out:
#                         addr:city addr:housenumber addr:state addr:street  \
# element_type osmid
# way          1110047265       NaN              NaN        NaN         NaN
#              25442796         NaN              NaN        NaN         NaN
#              1064302662       NaN              NaN        NaN         NaN
#              490746000        NaN              NaN        NaN         NaN
#              336926356        NaN              NaN        NaN         NaN
#
#                         addr:street_direction_prefix  \
# element_type osmid
# way          1110047265                          NaN
#              25442796                            NaN
#              1064302662                          NaN
#              490746000                           NaN
#              336926356                           NaN
#
#                                                source source_ref  \
# element_type osmid
# way          1110047265  microsoft/BuildingFootprints        NaN
#              25442796                             NaN        NaN
#              1064302662                           NaN        NaN
#              490746000                            NaN        NaN
#              336926356                           USGS        NaN
#
#                                                                   geometry  \
# element_type osmid
# way          1110047265  POLYGON ((-117.59491 34.03973, -117.59490 34.0...
#              25442796    POLYGON ((-117.60100 34.05036, -117.60171 34.0...
#              1064302662  POLYGON ((-117.61227 34.06454, -117.61260 34.0...
#              490746000   POLYGON ((-117.58318 34.06644, -117.58309 34.0...
#              336926356   POLYGON ((-117.58759 34.04174, -117.58608 34.0...
#
#                         name aeroway  ... website fixme note addr:country  \
# element_type osmid                    ...
# way          1110047265  NaN     NaN  ...     NaN   NaN  NaN          NaN
#              25442796    NaN     NaN  ...     NaN   NaN  NaN          NaN
#              1064302662  NaN     NaN  ...     NaN   NaN  NaN          NaN
#              490746000   NaN     NaN  ...     NaN   NaN  NaN          NaN
#              336926356   NaN     NaN  ...     NaN   NaN  NaN          NaN
#
#                         cuisine takeaway alt_name drive_through ways type
# element_type osmid
# way          1110047265     NaN      NaN      NaN           NaN  NaN  NaN
#              25442796       NaN      NaN      NaN           NaN  NaN  NaN
#              1064302662     NaN      NaN      NaN           NaN  NaN  NaN
#              490746000      NaN      NaN      NaN           NaN  NaN  NaN
#              336926356      NaN      NaN      NaN           NaN  NaN  NaN
#
# [5 rows x 45 columns]

# %% [markdown]
# ## Eliminate unnecessary columns

# %%
osm.info(verbose=True, show_counts=True)
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# MultiIndex: 137 entries, ('way', 25421022) to ('relation', 15511540)
# Data columns (total 45 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   addr:city                     24 non-null     object
#  1   addr:housenumber              23 non-null     object
#  2   addr:state                    24 non-null     object
#  3   addr:street                   23 non-null     object
#  4   addr:street_direction_prefix  7 non-null      object
#  5   source                        53 non-null     object
#  6   source_ref                    10 non-null     object
#  7   geometry                      137 non-null    geometry
#  8   name                          22 non-null     object
#  9   aeroway                       4 non-null      object
#  10  ref                           3 non-null      object
#  11  nodes                         137 non-null    object
#  12  addr:postcode                 20 non-null     object
#  13  airlines                      2 non-null      object
#  14  building                      137 non-null    object
#  15  government                    1 non-null      object
#  16  office                        1 non-null      object
#  17  phone                         6 non-null      object
#  18  amenity                       4 non-null      object
#  19  gnis:county_id                1 non-null      object
#  20  gnis:created                  1 non-null      object
#  21  gnis:feature_id               1 non-null      object
#  22  gnis:state_id                 1 non-null      object
#  23  email                         1 non-null      object
#  24  fax                           1 non-null      object
#  25  url                           1 non-null      object
#  26  owner                         1 non-null      object
#  27  brand                         10 non-null     object
#  28  brand:wikidata                10 non-null     object
#  29  brand:wikipedia               5 non-null      object
#  30  internet_access               2 non-null      object
#  31  internet_access:fee           2 non-null      object
#  32  layer                         1 non-null      object
#  33  official_name                 4 non-null      object
#  34  tourism                       7 non-null      object
#  35  website                       1 non-null      object
#  36  fixme                         1 non-null      object
#  37  note                          1 non-null      object
#  38  addr:country                  2 non-null      object
#  39  cuisine                       3 non-null      object
#  40  takeaway                      2 non-null      object
#  41  alt_name                      1 non-null      object
#  42  drive_through                 1 non-null      object
#  43  ways                          6 non-null      object
#  44  type                          6 non-null      object
# dtypes: geometry(1), object(44)
# memory usage: 53.9+ KB

# %%
## subset it
columns_to_keep = ['geometry','building']
osm = osm[columns_to_keep]
osm.head(5)
# Out:
#                                                                 geometry  \
# element_type osmid
# way          25421022  POLYGON ((-117.58822 34.06063, -117.58800 34.0...
#              25421169  POLYGON ((-117.61164 34.05181, -117.61111 34.0...
#              25421170  POLYGON ((-117.61214 34.05152, -117.61166 34.0...
#              25425661  POLYGON ((-117.60647 34.06173, -117.60639 34.0...
#              25425662  POLYGON ((-117.60971 34.05881, -117.61067 34.0...
#
#                       building
# element_type osmid
# way          25421022      yes
#              25421169      yes
#              25421170      yes
#              25425661      yes
#              25425662      yes

# %% [markdown]
# ### Cleaning up unspecified building types

# %%
osm.loc[osm['building']=='yes','building'] = 'unspecified'
osm.head(5)
# Out:
#                                                                 geometry  \
# element_type osmid
# way          25421022  POLYGON ((-117.58822 34.06063, -117.58800 34.0...
#              25421169  POLYGON ((-117.61164 34.05181, -117.61111 34.0...
#              25421170  POLYGON ((-117.61214 34.05152, -117.61166 34.0...
#              25425661  POLYGON ((-117.60647 34.06173, -117.60639 34.0...
#              25425662  POLYGON ((-117.60971 34.05881, -117.61067 34.0...
#
#                           building
# element_type osmid
# way          25421022  unspecified
#              25421169  unspecified
#              25421170  unspecified
#              25425661  unspecified
#              25425662  unspecified

# %% [markdown]
# # Make a building type chart

# %%
osm_building_counts = osm.value_counts(['building']).reset_index(name="count")
osm_building_counts
# Out:
#       building  count
# 0  unspecified    114
# 1   industrial      9
# 2   commercial      7
# 3    warehouse      5
# 4      trailer      1
# 5   university      1

# %% [markdown]
# # Geopandas Map Plots

# %%
# plot entire dataset
osm.plot(figsize=(10,10))
# Out:
# <AxesSubplot: >

# %%
fig, ax = plt.subplots(figsize=(10,10))

# create the map plot
osm.plot(ax=ax,
         column='building',
         cmap='tab20',
         legend=True,
         legend_kwds={'loc':'upper left','bbox_to_anchor':(1,.9)})

# add a title
ax.set_title('Building types in ' + address)

# get rid of the axis
ax.axis('off');

# %% [markdown]
# ### Calculate the map bounds of your data

# %%
# get min/max bounds of lat/lon
minx = osm.total_bounds[0]
miny = osm.total_bounds[1]
maxx = osm.total_bounds[2]
maxy = osm.total_bounds[3]

# %%
# reproject to Web Mercator
osm_web_mercator = osm.to_crs(epsg=3857)
# Able to measure distance in meter

fig, ax = plt.subplots(figsize=(8,8))

# create the map plot
osm.plot(ax=ax,
            # column='building',
            color='black')

# create the map plot
osm[osm['building'] == 'warehouse'].plot(ax=ax,
        # column='building',
        color='red')

# set the extent of the map 
# so that each map has the same bounds
ax.set_xlim((minx,maxx))
ax.set_ylim((miny,maxy))

# add a title
number_of_buildings = len(osm[osm['building']=='warehouse'])
ax.set_title(str(number_of_buildings) + '   warehouse buildings')

# get rid of the axis
ax.axis('off');

# basemap from carto that has a dark background (easier to see)
ctx.add_basemap(ax=ax,
                source=ctx.providers.CartoDB.Positron,
                alpha=1, # add transparency to make it less dominant
                zoom=14
                )

# %% [markdown]
# ## Create a function that generates a map based on any location

# %%
# function to create a map using open street map
def make_building_map(address):
 
    # get the data from osm
    osm = ox.geometries_from_address(address,
                                     tags={'building':True},
                                     dist=1609.34)
    
    
    # create the figure as a subplot
    fig,ax = plt.subplots(figsize=(8,8))
    
    # create the map plot
    osm.plot(ax=ax,
                # column='building',
                color='black')

    # create the map plot
    osm[osm['building'] == 'warehouse'].plot(ax=ax,
            # column='building',
            color='red')

    # add a title
    number_of_buildings = len(osm[osm['building']=='warehouse'])
    ax.set_title(str(number_of_buildings) + '   warehouse buildings within 1 mile')

    # get rid of the axis
    ax.axis('off')  
    
    # basemap from carto that has a dark background (easier to see)
    ctx.add_basemap(ax=ax,
                source=ctx.providers.CartoDB.Positron,
                alpha=1, # add transparency to make it less dominant
                zoom=14
                )

# %%
# %%time 
# a "magic" function to display the time it took to run this cell
# run the function once
make_building_map('Ontario International Airport, Vineyard Avenue, Racimo, Ontario, San Bernardino County, California, 91761, United States')
# Out:
# CPU times: user 372 ms, sys: 187 ms, total: 558 ms
# Wall time: 643 ms

# %% [markdown]
# # Create isochrones

# %%
from shapely.geometry import Point, Polygon

# %% [markdown]
# ## Download and prep the street network

# %%
# configure the place, network type, trip times, and travel speed
# latlon = [34.0633,-117.6509]
# address = 'Ontario International Airport, Vineyard Avenue, Racimo, Ontario, San Bernardino County, California, 91761, United States'

address ='Ontario International Airport, Vineyard Avenue, Racimo, Ontario, San Bernardino County, California, 91761, United States'
latlon = [34.0633,-117.6509]
network_type = 'walk'
distance = [402.336, 804.672, 1609.34] #in meters
meters_per_minute = 75 # travel distance per minute
cmap = 'plasma'
title = 'How many wareshouses are within 1 miles'

# %%
# Convert the address to a Point object
point = ox.geocode(address)

# %%
# download the street network
# Use OSMnx to create a graph of the street network within 1 miles of the address
G = ox.graph.graph_from_address(point, dist=1609.34,
                               network_type= network_type)

# %%
# quick plot using oxmnx
fig, ax = ox.plot_graph(G,figsize=(8,8))

# %% [markdown]
# The below code is not working

# %%
# Create a Polygon object representing a 10-meter buffer around the point
#buffer05 = Point(point).buffer(804.672)
#buffer025 = Point(point).buffer(402.336)
# Step 5: Intersect the street network with the buffer to get the graph within the buffer
# subgraph05 = ox.utils_graph.get_largest_component(ox.project_graph(ox.graph_from_polygon(buffer05))) is not working 

# Step 6: Plot the resulting graph
#fig, ax = ox.plot_graph(subgraph05, node_size=0)

# %% [markdown]
# ### Project to web mercator

# %%
# project our network data to Web Mercator (measurements are in meters)
G = ox.project_graph(G, to_crs='epsg:3857')

# %% [markdown]
# ## Convert edges and nodes to geodataframes

# %%
# convert nodes and edges to geodataframes
gdf_nodes, gdf_edges = ox.graph_to_gdfs(G)

# %%
gdf_nodes.sample(5)
# Out:
#                        y              x  street_count       lon        lat  \
# osmid
# 7158833432  7.584972e+06  994431.282415             3  8.933128  56.133169
# 1580900311  7.585388e+06  998121.367688             4  8.966277  56.135254
# 361489570   7.585156e+06  995583.450277             1  8.943478  56.134093
# 3135554556  7.584221e+06  997496.698365             4  8.960665  56.129410
# 4092564079  7.581674e+06  994910.924705             1  8.937437  56.116655
#
#            highway                        geometry
# osmid
# 7158833432     NaN  POINT (994431.282 7584971.721)
# 1580900311     NaN  POINT (998121.368 7585388.173)
# 361489570      NaN  POINT (995583.450 7585156.322)
# 3135554556     NaN  POINT (997496.698 7584220.718)
# 4092564079     NaN  POINT (994910.925 7581673.563)

# %%
gdf_nodes.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 1390 entries, 253932269 to 9880689617
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   y             1390 non-null   float64
#  1   x             1390 non-null   float64
#  2   street_count  1390 non-null   int64
#  3   lon           1390 non-null   float64
#  4   lat           1390 non-null   float64
#  5   highway       56 non-null     object
#  6   geometry      1390 non-null   geometry
# dtypes: float64(4), geometry(1), int64(1), object(1)
# memory usage: 86.9+ KB

# %%
gdf_edges.sample(5)
# Out:
#                                osmid  oneway  ref                   name  \
# u          v          key
# 1899630517 1899630518 0    179565842   False  NaN                    NaN
# 1587649780 1587649818 0    145345701   False  NaN  Mads Eg Damgaards Vej
# 1895330324 1895330322 0    179185445   False  NaN                    NaN
# 312289292  312289293  0     28424850   False  NaN           Hedelandsvej
# 1899629904 1899629906 0    179565741   False  NaN                    NaN
#
#                                highway maxspeed reversed  length  \
# u          v          key
# 1899630517 1899630518 0        footway      NaN    False   7.623
# 1587649780 1587649818 0       tertiary      NaN     True   7.863
# 1895330324 1895330322 0        footway      NaN    False  11.944
# 312289292  312289293  0    residential      NaN    False  86.286
# 1899629904 1899629906 0        footway      NaN     True   8.374
#
#                                                                     geometry  \
# u          v          key
# 1899630517 1899630518 0    LINESTRING (996795.608 7585403.116, 996809.301...
# 1587649780 1587649818 0    LINESTRING (994223.749 7585013.751, 994223.850...
# 1895330324 1895330322 0    LINESTRING (998299.323 7584200.484, 998282.926...
# 312289292  312289293  0    LINESTRING (994819.164 7583882.963, 994754.187...
# 1899629904 1899629906 0    LINESTRING (997279.614 7585067.527, 997264.686...
#
#                           lanes bridge service tunnel width access junction
# u          v          key
# 1899630517 1899630518 0     NaN    NaN     NaN    NaN   NaN    NaN      NaN
# 1587649780 1587649818 0       1    NaN     NaN    NaN   NaN    NaN      NaN
# 1895330324 1895330322 0     NaN    NaN     NaN    NaN   NaN    NaN      NaN
# 312289292  312289293  0     NaN    NaN     NaN    NaN   NaN    NaN      NaN
# 1899629904 1899629906 0     NaN    NaN     NaN    NaN   NaN    NaN      NaN

# %%
gdf_edges.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# MultiIndex: 3844 entries, (253932269, 297818546, 0) to (9880689617, 9880689623, 0)
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   osmid     3844 non-null   object
#  1   oneway    3844 non-null   bool
#  2   ref       94 non-null     object
#  3   name      1540 non-null   object
#  4   highway   3844 non-null   object
#  5   maxspeed  530 non-null    object
#  6   reversed  3844 non-null   object
#  7   length    3844 non-null   float64
#  8   geometry  3844 non-null   geometry
#  9   lanes     334 non-null    object
#  10  bridge    20 non-null     object
#  11  service   618 non-null    object
#  12  tunnel    12 non-null     object
#  13  width     42 non-null     object
#  14  access    2 non-null      object
#  15  junction  24 non-null     object
# dtypes: bool(1), float64(1), geometry(1), object(13)
# memory usage: 559.6+ KB

# %%
gdf_nodes.plot(figsize=(8,8))
# Out:
# <AxesSubplot: >

# %%
gdf_edges.plot(figsize=(8,8))
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Get the centroid

# %%
# get the bounding box coordinates
minx, miny, maxx, maxy = gdf_nodes.geometry.total_bounds
print(minx)
print(miny)
print(maxx)
print(maxy)
# Out:
# 992755.835023001
# 7579779.441078794
# 998532.5150948385
# 7585531.171114911

# %%
# calculate the centroid
centroid_x = (maxx-minx)/2 + minx
centroid_y = (maxy-miny)/2 + miny
print(centroid_x)
print(centroid_y)
# Out:
# 995644.1750589197
# 7582655.306096853

# %% [markdown]
# ## Get the nearest node to the lat/lon point

# %%
# use osmnx's distance.nearest_nodes command to get the id for the nearest node
center_node = ox.distance.nearest_nodes(G,Y=centroid_y,X=centroid_x)
print('The id for the nearest node is ' + str(center_node))
# Out:
# The id for the nearest node is 1599519637

# %%
# what is this record?
center_point=gdf_nodes.loc[[center_node]]

# %%
center_point
# Out:
#                        y              x  street_count       lon      lat  \
# osmid
# 1599519637  7.582641e+06  995644.219587             3  8.944024  56.1215
#
#            highway                        geometry
# osmid
# 1599519637     NaN  POINT (995644.220 7582641.008)

# %% [markdown]
# ## Map the network and building layers

# %%
# set up the subplot (single plot = ax)
fig, ax = plt.subplots(figsize=(10,10))

# add the edges to ax
gdf_edges.plot(ax=ax,
              linewidth=0.5,
               edgecolor='gray', 
               zorder=10)

# add all nodes to ax
gdf_nodes.plot(ax=ax, 
              markersize=2, 
              zorder=20)

# create the map plot
# osm.plot(ax=ax,
        # column='building',
        # color='black')

# create the map plot
#osm[osm['building'] == 'warehouse'].plot(ax=ax,
 #       column='building',
  #      color='red')

# add the center node in red also to ax
gdf_nodes.loc[[center_node]].plot(ax=ax,
                                  color='r', 
                                  zorder=30)

# no axis
ax.axis('off')

# add a basemap
ctx.add_basemap(ax,source=ctx.providers.CartoDB.Positron)

# %% [markdown]
# ## Create the buffer radius

# %%
# Define the buffer radius (in meters)
buffer025 = 402.336
buffer05 = 804.672
buffer1 = 1609.34

# %%
# Create the buffer around the center point

buffer_025 = center_point.buffer(buffer025)
buffer_05 = center_point.buffer(buffer05)
buffer_1 = center_point.buffer(buffer1)

# %%
# Plot buffer_025
buffer_025.plot()
# Out:
# <AxesSubplot: >

# %%
# Plot buffer_05
buffer_05.plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Choosing colors (cmap) for our isochrones

# %%
# choose a colormap
cmap = 'RdYlGn'

# %%
# assign a color hex code for each trip time isochrone
iso_colors = ox.plot.get_colors(n=len(distance), 
                                cmap=cmap, 
                                start=0, 
                                return_hex=True)
print(distance)
print(iso_colors)
# Out:
# [402.336, 804.672, 1609.34]
# ['#a50026', '#feffbe', '#006837']

# %%
# create a list of "zipped" time/colors
distance_color = list(zip(distance, iso_colors))
distance_color
# Out:
# [(402.336, '#a50026'), (804.672, '#feffbe'), (1609.34, '#006837')]

# %%
# loop through the list of time/colors
for distance,color in list(distance_color):
    print('The color for '+str(distance)+' meters is ' + color)
# Out:
# The color for 402.336 meters is #a50026
# The color for 804.672 meters is #feffbe
# The color for 1609.34 meters is #006837

# %% [markdown]
# ## Color each node based on travel time from point of interest

# %%
# reverse the order so that outside nodes get associated first
distance_color.reverse()
# time_color.sort(reverse=True)
distance_color
# Out:
# [(1609.34, '#006837'), (804.672, '#feffbe'), (402.336, '#a50026')]

# %%
# loop through each trip time and associated color
for distance, color in list(distance_color):

    # for each trip time, create an egograph of nodes that fall within that distance
    subgraph = nx.ego_graph(G, center_node, radius=distance,distance="length")

    print('There are ' + str(len(subgraph.nodes())) + ' nodes within ' + str(distance) + ' meters ' + color)
    
    # for each of those nodes, update the gdf_nodes dataframe and assign it with its associated distance color
    for node in subgraph.nodes():
        gdf_nodes.loc[node,'distance'] = distance
        gdf_nodes.loc[node,'color'] = color
# Out:
# There are 508 nodes within 1609.34 meters #006837
# There are 276 nodes within 804.672 meters #feffbe
# There are 113 nodes within 402.336 meters #a50026

# %%
# spot check
gdf_nodes.sample(5)
# Out:
#                        y              x  street_count       lon        lat  \
# osmid
# 7856231895  7.582391e+06  995997.414067             3  8.947197  56.120248
# 1899630266  7.585286e+06  997209.928225             3  8.958089  56.134744
# 5077767231  7.583181e+06  995980.571428             3  8.947046  56.124203
# 4610071126  7.585226e+06  998115.334171             1  8.966223  56.134441
# 1909521922  7.585501e+06  996076.818260             3  8.947910  56.135817
#
#            highway                        geometry  distance    color
# osmid
# 7856231895     NaN  POINT (995997.414 7582391.008)   402.336  #a50026
# 1899630266     NaN  POINT (997209.928 7585286.351)       NaN      NaN
# 5077767231     NaN  POINT (995980.571 7583180.876)   804.672  #feffbe
# 4610071126     NaN  POINT (998115.334 7585225.781)       NaN      NaN
# 1909521922     NaN  POINT (996076.818 7585500.685)       NaN      NaN

# %%
# the NaN values then need to be populated with a valid color
gdf_nodes['color'].fillna('#cccccc', inplace=True)

# %%
# another spot check: are all values in the color column populated?
gdf_nodes.sample(5)
# Out:
#                        y              x  street_count       lon        lat  \
# osmid
# 4092564079  7.581674e+06  994910.924705             1  8.937437  56.116655
# 1899630180  7.585218e+06  996823.170918             3  8.954615  56.134402
# 1272527935  7.580985e+06  995639.956050             3  8.943986  56.113208
# 7158833428  7.585192e+06  994699.662575             3  8.935539  56.134274
# 1895365601  7.584713e+06  997615.442866             1  8.961732  56.131872
#
#            highway                        geometry  distance    color
# osmid
# 4092564079     NaN  POINT (994910.925 7581673.563)   1609.34  #006837
# 1899630180     NaN  POINT (996823.171 7585217.930)       NaN  #cccccc
# 1272527935     NaN  POINT (995639.956 7580985.255)   1609.34  #006837
# 7158833428     NaN  POINT (994699.663 7585192.340)       NaN  #cccccc
# 1895365601     NaN  POINT (997615.443 7584712.516)       NaN  #cccccc

# %%
# map it
gdf_nodes.plot(figsize=(10,10),
               color=gdf_nodes['color'],
               markersize=3,
               )
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Create polygons for each distance area

# %%
# put the 1/4 mile nodes in a variable
gdf_025 = gdf_nodes[gdf_nodes['distance']==402.336]

# %%
# plot it
gdf_025.plot()
# Out:
# <AxesSubplot: >

# %%
# combine all the points (unary_union) and create a convex hull polygon
gdf_025.unary_union.convex_hull
# Out:
# <POLYGON ((996003.882 7582224.605, 995925.591 7582225.524, 995906.678 758223...>

# %% [markdown]
# ## Dissolve to the rescue!

# %%
# dissolve the nodes by time
# adding the "time" argument creates a separate geometry (multipoint in this case) for each unique time category
isochrones = gdf_nodes.dissolve(by = "distance")
isochrones
# Out:
#                                                    geometry             y  \
# distance
# 402.336   MULTIPOINT (995593.970 7582553.201, 995600.093...  7.582998e+06
# 804.672   MULTIPOINT (995247.956 7581985.122, 995343.791...  7.582976e+06
# 1609.340  MULTIPOINT (994342.372 7583682.654, 994437.806...  7.584308e+06
#
#                       x  street_count       lon        lat          highway  \
# distance
# 402.336   995854.212674             3  8.945911  56.123290         crossing
# 804.672   996321.899251             3  8.950112  56.123177  traffic_signals
# 1609.340  994972.261744             3  8.937988  56.129846  traffic_signals
#
#             color
# distance
# 402.336   #a50026
# 804.672   #feffbe
# 1609.340  #006837

# %%
# for each row, create a convex hull
isochrones = isochrones.convex_hull.reset_index(name='geometry')
isochrones
# Out:
#    distance                                           geometry
# 0   402.336  POLYGON ((996003.882 7582224.605, 995925.591 7...
# 1   804.672  POLYGON ((995846.699 7581573.307, 995404.949 7...
# 2  1609.340  POLYGON ((995339.171 7580376.704, 995045.733 7...

# %%
# reverse the order so that outer polygon gets drawn first
isochrones.sort_values(by='distance', ascending=False,inplace=True)
isochrones
# Out:
#    distance                                           geometry
# 2  1609.340  POLYGON ((995339.171 7580376.704, 995045.733 7...
# 1   804.672  POLYGON ((995846.699 7581573.307, 995404.949 7...
# 0   402.336  POLYGON ((996003.882 7582224.605, 995925.591 7...

# %%
# reverse the colors too!
iso_colors.reverse()
iso_colors
# Out:
# ['#006837', '#feffbe', '#a50026']

# %%
isochrones.plot(figsize=(10,10),alpha=1,color=iso_colors, legend=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Bring the buffers together and add custome legend

# %%
# to draw custom legend elements, import these libraries
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

# %%
# set up the subplots
fig, ax = plt.subplots(figsize=(10,15))

# add the isochrone boundary
isochrones.boundary.plot(
    ax=ax,
    alpha=1,
    linestyle='--',
    color=iso_colors,
    lw=2
    ) 

# add the isochrones
isochrones.plot(
    ax=ax, 
    alpha=0.2, 
    categorical=True, # even though it is numeric, treat it as categorical
    color=iso_colors,
    )

# add the 1/4 mile buffer
buffer_025.plot(
    ax=ax, 
    alpha=0.2, 
    color='r'
    )

# add the 1/2 mile buffer
buffer_05.plot(
    ax=ax, 
    alpha=0.2, 
    color='y'
    )

# add the 1 mile buffer
buffer_1.plot(
    ax=ax, 
    alpha=0.2, 
    color='g'
    )

# add the center node in red
gdf_nodes.loc[[center_node]].plot(ax=ax,color='r',marker='x',markersize=50)


# build custom legend
legend_elements = [
    # add the center node to the legend
    Line2D([0], [0], marker='x', color='red', linestyle='',label='Start location', markersize=6)
    ]

# sort back to small time to large time
# time_color.sort(reverse=False)
distance_color.reverse()

# loop through the list of distance/colors and add each to the legend
for distance,color in list(distance_color):
    legend_item = Patch(facecolor=color, edgecolor=color, linestyle='--',linewidth=1,label=str(distance)+' meters',alpha=0.4)
    legend_elements.append(legend_item)

buffers = [402.336, 804.672, 1609.34]
for buffer in buffers:
    legend_item = Patch(facecolor='r', linestyle='--',linewidth=1,label=str(buffer)+' meters',alpha=0.4)
    legend_elements.append(legend_item)


# add the legend
ax.legend(handles=legend_elements,loc='lower left')


# add a title
ax.set_title('How many warehouses are contained in the distance?',fontsize=25,pad=20)

# hide the axis
ax.axis('off')

# add the basemap
ctx.add_basemap(ax,source=ctx.providers.CartoDB.Positron)

# %% [markdown]
# ## Bring in warehouse data

# %%
Warehouses = pd.read_csv('../weekly tasks/week 4/Warehouse Data Exploration - Matthews/Data/Warehouse_Data.csv',
        dtype=
        {
            'Assessor parcel number':str,
            'Building classification':str,
        }
)

San_Bern_Parcels = gpd.read_file('../weekly tasks/week 4/Warehouse Data Exploration - Matthews/Data/Ontario Parcels/SBCo_Parcel_Polygons.shp')

San_Bern_Parcels.rename(columns = {'ParcelNumb':'Assessor parcel number'}, inplace = True)

#merge the warehouses and parcel shapefile on the San Bernandino County Tax Assessor parcel Number
Warehouse_Parcel=Warehouses.merge(San_Bern_Parcels,on="Assessor parcel number")
Warehouse_Parcel_Geo = gpd.GeoDataFrame(Warehouse_Parcel, geometry='geometry', crs="EPSG:3857")

# %%
# Check the wareshouse dataframe crs
Warehouse_Parcel_Geo.crs
# Out:
# <Derived Projected CRS: EPSG:3857>
# Name: WGS 84 / Pseudo-Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: World between 85.06°S and 85.06°N.
# - bounds: (-180.0, -85.06, 180.0, 85.06)
# Coordinate Operation:
# - name: Popular Visualisation Pseudo-Mercator
# - method: Popular Visualisation Pseudo Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
# Get the centroid of the warehouse and plot it
Warehouse_Parcel_Geo.centroid.plot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## Map everything together

# %%
# set up the subplots
fig, ax = plt.subplots(figsize=(10,15))

# add the isochrone boundary
isochrones.boundary.plot(
    ax=ax,
    alpha=1,
    linestyle='--',
    color=iso_colors,
    lw=2
    ) 

# add the isochrones
isochrones.plot(
    ax=ax, 
    alpha=0.2, 
    categorical=True, # even though it is numeric, treat it as categorical
    color=iso_colors,
    )

# add the 1/4 mile buffer
buffer_025.plot(
    ax=ax, 
    alpha=0.2, 
    color='r'
    )

# add the 1/2 mile buffer
buffer_05.plot(
    ax=ax, 
    alpha=0.2, 
    color='y'
    )

# add the 1 mile buffer
buffer_1.plot(
    ax=ax, 
    alpha=0.2, 
    color='g'
    )

# add wareshouse location 
Warehouse_Parcel_Geo.plot(ax=ax, color='red',markersize=2)

# add the center node in red
gdf_nodes.loc[[center_node]].plot(ax=ax,color='r',marker='x',markersize=50)

# hide the axis
ax.axis('off')

# add the basemap
ctx.add_basemap(ax,source=ctx.providers.CartoDB.Positron, crs="EPSG:3857")
